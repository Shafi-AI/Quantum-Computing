# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()

# %%
n_q = 8
n_b = 8
qc_output =  QuantumCircuit(n_q, n_b)

# %%
n= 8 
for j in range(n):
    qc_output.measure(j,j)

# %%
qc_output.draw(output='mpl')

# %%
counts = execute(qc_output, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %% [markdown]
# Encoding an input : Creating a new circuit dedicated to the encoding and call it as qc_encode , Here we specify number of Qubits.

# %%
n= 8
qc_encode = QuantumCircuit(n)
qc_encode.x(7)
qc_encode.draw('mpl')

# %% [markdown]
# Addig two circuits qc_output and qc_encode to obtain a new circuit that
# we need to extract an output added at the end

# %%
qc = qc_encode + qc_output
qc.draw(output ='mpl', justify = 'none' )

# %% [markdown]
# now we can run the combined circuit and look at the results

# %%
couts = execute(qc , Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
# another example on encode 
qc_encode = QuantumCircuit(n)
qc_encode.x(1)
qc_encode.x(5)
qc_encode.draw('mpl')

# %% [markdown]
# Half Adder Circuit Example
# Describing step-by-step

# %%
qc_cnot  = QuantumCircuit(2)
qc_cnot.cx(0,1)
qc_cnot.draw('mpl')

# %%
qc = QuantumCircuit(2,2)
qc.x(0)
qc.cx(0,1)
qc.measure(0,0)
qc.measure(1,1)
qc.draw('mpl')

# %%
qc_ha = QuantumCircuit(4,2)
qc_ha.x(0)
qc_ha.x(1)
qc_ha.barrier()

qc_ha.cx(0,2)
qc_ha.cx(0,1)
qc_ha.barrier()

qc_ha.measure(2,0)
qc_ha.measure(3,1)

qc_ha.draw('mpl')

# %%
qc_ha= QuantumCircuit(4,2)
qc_ha.x(0)
qc_ha.x(1)
qc_ha.barrier()

qc_ha.cx(0,2)
qc_ha.cx(1,2)

qc_ha.ccx(0,1,3)
qc_ha.barrier()


qc_ha.measure(2,0)
qc_ha.measure(3,1)

qc_ha.draw('mpl')

# %%
counts = execute(qc_ha, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)
